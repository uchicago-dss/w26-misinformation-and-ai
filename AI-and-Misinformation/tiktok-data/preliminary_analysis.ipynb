# %%
import pandas as pd

# %%
df = pd.read_csv("./data/raw_data.csv")
df_clean = df.dropna(subset=["likes", "views", "shares"])
df
# Out:
#      source              tag             video_id  \
# 0    TikTok  OliviaHenderson  7573038672262466830
# 1    TikTok  OliviaHenderson  7591774242346257677
# 2    TikTok  OliviaHenderson  7573068947105320222
# 3    TikTok  OliviaHenderson  7573593663788436749
# 4    TikTok  OliviaHenderson  7581702595585068319
# ..      ...              ...                  ...
# 298  TikTok     DoordashGirl  7597463653566237983
# 299  TikTok     DoordashGirl  7563679786480979231
# 300  TikTok     DoordashGirl  7249365952163302682
# 301  TikTok     DoordashGirl  7563480727531048222
# 302  TikTok     DoordashGirl  7562975268508421431
#
#                         post_date_utc  \
# 0    2015-01-21T09:47:15.468000+00:00
# 1    2015-01-21T10:59:57.683000+00:00
# 2    2015-01-21T09:47:22.517000+00:00
# 3    2015-01-21T09:49:24.687000+00:00
# 4    2015-01-21T10:20:52.695000+00:00
# ..                                ...
# 298  2015-01-21T11:22:02.352000+00:00
# 299  2015-01-21T09:10:56.433000+00:00
# ...

# %% [markdown]
# **Means and Medians**

# %%
cols = [
    "likes",
    "views",
    "shares",
    "comments",
    "author_following_count",
    "author_total_likes",
    "author_video_count",
]

summary = df[cols].agg(["mean", "median", "std", "max", "min"]).round(2)
print(summary)
# Out:
#              likes        views     shares  comments  author_following_count  \
# mean      47513.92    640395.10    1910.41    881.52                  877.89
# median      588.00     37700.00      23.00     38.00                   77.00
# std      316658.08   3048566.51   13323.06   4706.67                 1799.39
# max     4000000.00  36100000.00  164000.00  71100.00                 9998.00
# min           0.00        39.00       0.00      0.00                    0.00
#
#         author_total_likes  author_video_count
# mean          6.185009e+06              713.97
# median        2.306000e+05              237.00
# std           1.917004e+07             1125.94
# max           1.930000e+08             7151.00
# min           4.000000e+00                1.00
